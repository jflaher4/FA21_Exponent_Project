# %%
# Important statistical libraries
import numpy as np
import pandas as pd
from scipy import stats
# Some graphing libraries
from matplotlib import pyplot as plt

# %%
# Import train dataset into dataframe
df = pd.read_csv('train.csv')

# %%
x = 'LotArea'
y = 'SalePrice'
plt.scatter(df[x],df[y])
plt.title(f'{x} vs. {y} Scatterplot')
plt.xlabel(x)
plt.ylabel(y)
plt.show()

# %%
x = 'ExterQual'
plt.hist(df[x])
plt.xlabel("Exterior Quality")
plt.ylabel("Count")
# how to change the labels for each bar? ('Gd' to 'Good', etc.)?
# Out:
# Text(0, 0.5, 'Count')

# %%
x = 'OverallQual'
plt.hist(df[x])
plt.xlabel("Overall Quality")
plt.ylabel("Count")
# how to separate the bars to make the graph more readable?
# Out:
# Text(0, 0.5, 'Count')

# %%
# how to make frequency polygon?
