# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import PolynomialFeatures

# %%
df = pd.read_csv('../Data/train.csv')
test = pd.read_csv('../Data/test.csv')
test.head(5)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df['TotalSF'] = df['GrLivArea'] + df['TotalBsmtSF']
df_reg = df[['SalePrice','TotalSF']]
df_reg.head(5)
# Out:
#    SalePrice  TotalSF
# 0     208500     2566
# 1     181500     2524
# 2     223500     2706
# 3     140000     2473
# 4     250000     3343

# %%
x = np.array(df['TotalSF']).reshape(-1, 1)
y = np.array(df['SalePrice']).reshape(-1, 1)
#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25)

reg = LinearRegression()
  
reg.fit(x, y)
print(reg.score(x, y))
# Out:
# 0.6067768572680559

# %%
y_prediction = reg.predict(x)
plt.scatter(x, y, color ='b')
plt.plot(x, y_prediction, color ='k')
  
plt.show()

# %%
x = np.array(df[['TotalSF','GarageArea']]).reshape(-1, 2)
y = np.array(df['SalePrice']).reshape(-1, 1)

poly = PolynomialFeatures(2)
x_ = poly.fit_transform(x)

reg.fit(x_, y_train)
print(reg.score(x_, y))
# Out:
# 0.7009644949694347
